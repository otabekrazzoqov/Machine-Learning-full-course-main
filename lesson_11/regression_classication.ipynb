# %% [markdown]
# # Model Review

# %%
import pandas as pd
df=pd.read_csv('df_merged.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20926 entries, 0 to 20925
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20926 non-null  int64
#  1   player_name   20925 non-null  object
#  2   games         20925 non-null  float64
#  3   time          20925 non-null  float64
#  4   goals         20925 non-null  float64
#  5   xG            20925 non-null  float64
#  6   assists       20925 non-null  float64
#  7   xA            20925 non-null  float64
#  8   shots         20925 non-null  float64
#  9   key_passes    20925 non-null  float64
#  10  yellow_cards  20925 non-null  float64
#  11  red_cards     20925 non-null  float64
#  12  position      20925 non-null  object
#  13  team_title    20925 non-null  object
#  14  npg           20925 non-null  float64
#  15  npxG          20925 non-null  float64
#  16  xGChain       20925 non-null  float64
#  17  xGBuildup     20925 non-null  float64
#  18  league        20925 non-null  object
#  19  season        20925 non-null  float64
# dtypes: float64(15), int64(1), object(4)
# memory usage: 3.2+ MB

# %%
df.isnull().sum()
# Out:
# id              0
# player_name     0
# games           1
# time            1
# goals           1
# xG              1
# assists         1
# xA              1
# shots           1
# key_passes      1
# yellow_cards    1
# red_cards       1
# position        0
# team_title      0
# npg             1
# npxG            1
# xGChain         1
# xGBuildup       1
# league          0
# season          1
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
encoder=LabelEncoder()

# %%
for col in df.columns:
    if df[col].dtype=='object':
        df[col]=encoder.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20926 entries, 0 to 20925
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20926 non-null  int64
#  1   player_name   20926 non-null  int32
#  2   games         20925 non-null  float64
#  3   time          20925 non-null  float64
#  4   goals         20925 non-null  float64
#  5   xG            20925 non-null  float64
#  6   assists       20925 non-null  float64
#  7   xA            20925 non-null  float64
#  8   shots         20925 non-null  float64
#  9   key_passes    20925 non-null  float64
#  10  yellow_cards  20925 non-null  float64
#  11  red_cards     20925 non-null  float64
#  12  position      20926 non-null  int32
#  13  team_title    20926 non-null  int32
#  14  npg           20925 non-null  float64
#  15  npxG          20925 non-null  float64
#  16  xGChain       20925 non-null  float64
#  17  xGBuildup     20925 non-null  float64
#  18  league        20926 non-null  int32
#  19  season        20925 non-null  float64
# dtypes: float64(15), int32(4), int64(1)
# memory usage: 2.9 MB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20925 entries, 0 to 20925
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20925 non-null  int64
#  1   player_name   20925 non-null  int32
#  2   games         20925 non-null  float64
#  3   time          20925 non-null  float64
#  4   goals         20925 non-null  float64
#  5   xG            20925 non-null  float64
#  6   assists       20925 non-null  float64
#  7   xA            20925 non-null  float64
#  8   shots         20925 non-null  float64
#  9   key_passes    20925 non-null  float64
#  10  yellow_cards  20925 non-null  float64
#  11  red_cards     20925 non-null  float64
#  12  position      20925 non-null  int32
#  13  team_title    20925 non-null  int32
#  14  npg           20925 non-null  float64
#  15  npxG          20925 non-null  float64
#  16  xGChain       20925 non-null  float64
#  17  xGBuildup     20925 non-null  float64
#  18  league        20925 non-null  int32
#  19  season        20925 non-null  float64
# dtypes: float64(15), int32(4), int64(1)
# memory usage: 3.0 MB

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('goals',axis=1)

# %%
y=df['goals']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model=LinearRegression()

# %%
lr_model
# Out:
# LinearRegression()

# %%
lr_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr_model.predict(x_test)

# %%
y_pred
# Out:
# array([ 2.15650056e-03,  3.62534206e+00,  7.75155159e+00, ...,
#        -1.03299851e-03,  1.55454552e+01,  6.57299215e+00])

# %%
# y_pred=lr_model.predict(x_train)

# %%
y_pred
# Out:
# array([ 2.15650056e-03,  3.62534206e+00,  7.75155159e+00, ...,
#        -1.03299851e-03,  1.55454552e+01,  6.57299215e+00])

# %%
from sklearn.metrics import r2_score, mean_absolute_error

# %%
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)

# %%
print(r2)
print(mae)
# Out:
# 0.9969827704091797
# 0.055300062297457424

# %% [markdown]
# # Logistic Regression

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20925 entries, 0 to 20925
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20925 non-null  int64
#  1   player_name   20925 non-null  int32
#  2   games         20925 non-null  float64
#  3   time          20925 non-null  float64
#  4   goals         20925 non-null  float64
#  5   xG            20925 non-null  float64
#  6   assists       20925 non-null  float64
#  7   xA            20925 non-null  float64
#  8   shots         20925 non-null  float64
#  9   key_passes    20925 non-null  float64
#  10  yellow_cards  20925 non-null  float64
#  11  red_cards     20925 non-null  float64
#  12  position      20925 non-null  int32
#  13  team_title    20925 non-null  int32
#  14  npg           20925 non-null  float64
#  15  npxG          20925 non-null  float64
#  16  xGChain       20925 non-null  float64
#  17  xGBuildup     20925 non-null  float64
#  18  league        20925 non-null  int32
#  19  season        20925 non-null  float64
# dtypes: float64(15), int32(4), int64(1)
# memory usage: 3.0 MB

# %%
df.head()
# Out:
#      id  player_name  games    time  goals         xG  assists        xA  \
# 0  1513         4392   36.0  2897.0   22.0  20.040535      6.0  4.607650
# 1  1955         3823   38.0  3228.0   22.0  21.204769      2.0  2.914252
# 2  3848          989   32.0  2594.0   20.0  13.372144      7.0  5.016580
# 3  1293         2355   37.0  2786.0   18.0  21.097412      7.0  4.082174
# 4  2014         3369   33.0  2713.0   16.0  10.936869      4.0  4.379692
#
#    shots  key_passes  yellow_cards  red_cards  position  team_title   npg  \
# 0  121.0        34.0           4.0        0.0        10         346  18.0
# 1  125.0        27.0           3.0        0.0        10         536  18.0
# 2  114.0        61.0           6.0        0.0         9         354  18.0
# 3  113.0        49.0           5.0        0.0        10         441  15.0
# 4   78.0        46.0           3.0        1.0         9           0   8.0
#
#         npxG    xGChain  xGBuildup  league  season
# 0  16.234041  23.242989   4.910617       0  1415.0
# 1  16.636976  18.810562   3.106042       0  1415.0
# 2  10.327029  20.007632   8.907537       0  1415.0
# 3  15.768320  22.711577   4.917353       0  1415.0
# 4   4.846598  13.755916   6.889687       0  1415.0

# %%
df['league'].nunique()
# Out:
# 5

# %%
x=df.drop('league',axis=1)

# %%
y=df['league']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression()

# %%
log_model.fit(x_train,y_train)
# Out:
# c:\Users\davro\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=log_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(y_test,y_pred)

# %%
print(score)
# Out:
# 0.33500597371565116
