# %% [markdown]
# # Encoding

# %%
import pandas as pd
df=pd.read_csv('metadata_bundesliga_1415.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            453 non-null    int64
#  1   player_name   453 non-null    object
#  2   games         453 non-null    int64
#  3   time          453 non-null    int64
#  4   goals         453 non-null    int64
#  5   xG            453 non-null    float64
#  6   assists       453 non-null    int64
#  7   xA            453 non-null    float64
#  8   shots         453 non-null    int64
#  9   key_passes    453 non-null    int64
#  10  yellow_cards  453 non-null    int64
#  11  red_cards     453 non-null    int64
#  12  position      453 non-null    object
#  13  team_title    453 non-null    object
#  14  npg           453 non-null    int64
#  15  npxG          453 non-null    float64
#  16  xGChain       453 non-null    float64
#  17  xGBuildup     453 non-null    float64
# ...

# %%
#drop
#1 ustun boyicha

# %%
df.drop('Size',axis=1,inplace=True)

# %%
df.drop(columns=[['Size','id']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.drop(columns=[['Size','id']])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            453 non-null    int64
#  1   player_name   453 non-null    object
#  2   games         453 non-null    int64
#  3   time          453 non-null    int64
#  4   goals         453 non-null    int64
#  5   xG            453 non-null    float64
#  6   assists       453 non-null    int64
#  7   xA            453 non-null    float64
#  8   shots         453 non-null    int64
#  9   key_passes    453 non-null    int64
#  10  yellow_cards  453 non-null    int64
#  11  red_cards     453 non-null    int64
#  12  position      453 non-null    object
#  13  team_title    453 non-null    object
#  14  npg           453 non-null    int64
#  15  npxG          453 non-null    float64
#  16  xGChain       453 non-null    float64
#  17  xGBuildup     453 non-null    float64
# ...

# %%
# dropni qator boyicha tashlab
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 3
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            4 non-null      int64
#  1   player_name   4 non-null      object
#  2   games         4 non-null      int64
#  3   time          4 non-null      int64
#  4   goals         4 non-null      int64
#  5   xG            4 non-null      float64
#  6   assists       4 non-null      int64
#  7   xA            4 non-null      float64
#  8   shots         4 non-null      int64
#  9   key_passes    4 non-null      int64
#  10  yellow_cards  4 non-null      int64
#  11  red_cards     4 non-null      int64
#  12  position      4 non-null      object
#  13  team_title    4 non-null      object
#  14  npg           4 non-null      int64
#  15  npxG          4 non-null      float64
#  16  xGChain       4 non-null      float64
#  17  xGBuildup     4 non-null      float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            453 non-null    int64
#  1   player_name   453 non-null    object
#  2   games         453 non-null    int64
#  3   time          453 non-null    int64
#  4   goals         453 non-null    int64
#  5   xG            453 non-null    float64
#  6   assists       453 non-null    int64
#  7   xA            453 non-null    float64
#  8   shots         453 non-null    int64
#  9   key_passes    453 non-null    int64
#  10  yellow_cards  453 non-null    int64
#  11  red_cards     453 non-null    int64
#  12  position      453 non-null    object
#  13  team_title    453 non-null    object
#  14  npg           453 non-null    int64
#  15  npxG          453 non-null    float64
#  16  xGChain       453 non-null    float64
#  17  xGBuildup     453 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# id                0
# player_name       0
# games             0
# time              0
# goals             0
# xG                0
# assists           0
# xA                0
# shots             0
# key_passes        0
# yellow_cards      0
# red_cards         0
# position          0
# team_title        0
# npg               0
# npxG              0
# xGChain           0
# xGBuildup         0
# Size            449
# dtype: int64

# %%
df['Size'].fillna(df['Size'].mode()[0],inplace=True)

# %%
df.nunique()
# Out:
# id              453
# player_name     453
# games            34
# time            397
# goals            17
# xG              391
# assists          13
# xA              389
# shots            76
# key_passes       59
# yellow_cards     12
# red_cards         3
# position         14
# team_title       26
# npg              16
# npxG            391
# xGChain         432
# xGBuildup       419
# Size              4
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            453 non-null    int64
#  1   player_name   453 non-null    object
#  2   games         453 non-null    int64
#  3   time          453 non-null    int64
#  4   goals         453 non-null    int64
#  5   xG            453 non-null    float64
#  6   assists       453 non-null    int64
#  7   xA            453 non-null    float64
#  8   shots         453 non-null    int64
#  9   key_passes    453 non-null    int64
#  10  yellow_cards  453 non-null    int64
#  11  red_cards     453 non-null    int64
#  12  position      453 non-null    object
#  13  team_title    453 non-null    object
#  14  npg           453 non-null    int64
#  15  npxG          453 non-null    float64
#  16  xGChain       453 non-null    float64
#  17  xGBuildup     453 non-null    float64
# ...

# %% [markdown]
# # One- Hot encoding

# %%
dummies=pd.get_dummies(df['player_name'],prefix='ustun',dtype=int)

# %%
dummies
# Out:
#      ustun_Aaron Hunt  ustun_Abdul Rahman Baba  ustun_Adam Hlousek  \
# 0                   0                        0                   0
# 1                   0                        0                   0
# 2                   0                        0                   0
# 3                   0                        0                   0
# 4                   0                        0                   0
# ..                ...                      ...                 ...
# 448                 0                        0                   0
# 449                 0                        0                   0
# 450                 0                        0                   0
# 451                 0                        0                   0
# 452                 0                        0                   0
#
#      ustun_Adam Matuschyk  ustun_Admir Mehmedi  ustun_Adrián Ramos  \
# 0                       0                    0                   0
# ...

# %%
df=pd.concat([df.drop(columns=['player_name']),dummies],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Columns: 471 entries, id to ustun_Özkan Yildirim
# dtypes: float64(5), int32(453), int64(10), object(3)
# memory usage: 865.4+ KB

# %%
df=pd.concat(df_1,df_2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            453 non-null    int64
#  1   player_name   453 non-null    object
#  2   games         453 non-null    int64
#  3   time          453 non-null    int64
#  4   goals         453 non-null    int64
#  5   xG            453 non-null    float64
#  6   assists       453 non-null    int64
#  7   xA            453 non-null    float64
#  8   shots         453 non-null    int64
#  9   key_passes    453 non-null    int64
#  10  yellow_cards  453 non-null    int64
#  11  red_cards     453 non-null    int64
#  12  position      453 non-null    object
#  13  team_title    453 non-null    object
#  14  npg           453 non-null    int64
#  15  npxG          453 non-null    float64
#  16  xGChain       453 non-null    float64
#  17  xGBuildup     453 non-null    float64
# ...

# %%
df['Size']
# Out:
# 0       XL
# 1        S
# 2       MS
# 3      2XL
# 4      2XL
#       ...
# 448    2XL
# 449    2XL
# 450    2XL
# 451    2XL
# 452    2XL
# Name: Size, Length: 453, dtype: object

# %% [markdown]
# # Label Encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            453 non-null    int64
#  1   player_name   453 non-null    object
#  2   games         453 non-null    int64
#  3   time          453 non-null    int64
#  4   goals         453 non-null    int64
#  5   xG            453 non-null    float64
#  6   assists       453 non-null    int64
#  7   xA            453 non-null    float64
#  8   shots         453 non-null    int64
#  9   key_passes    453 non-null    int64
#  10  yellow_cards  453 non-null    int64
#  11  red_cards     453 non-null    int64
#  12  position      453 non-null    object
#  13  team_title    453 non-null    object
#  14  npg           453 non-null    int64
#  15  npxG          453 non-null    float64
#  16  xGChain       453 non-null    float64
#  17  xGBuildup     453 non-null    float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
encoder
# Out:
# LabelEncoder()

# %%
df['player_name']=encoder.fit_transform(df['player_name'])

# %%
df['player_name']=encoder.transform(df['player_name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_encode.py:225, in _encode(values, uniques, check_unknown)
#     224 try:
# --> 225     return _map_to_integer(values, uniques)
#     226 except KeyError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_encode.py:165, in _map_to_integer(values, uniques)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_encode.py:165, in <listcomp>(.0)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            453 non-null    int64
#  1   player_name   453 non-null    int32
#  2   games         453 non-null    int64
#  3   time          453 non-null    int64
#  4   goals         453 non-null    int64
#  5   xG            453 non-null    float64
#  6   assists       453 non-null    int64
#  7   xA            453 non-null    float64
#  8   shots         453 non-null    int64
#  9   key_passes    453 non-null    int64
#  10  yellow_cards  453 non-null    int64
#  11  red_cards     453 non-null    int64
#  12  position      453 non-null    object
#  13  team_title    453 non-null    object
#  14  npg           453 non-null    int64
#  15  npxG          453 non-null    float64
#  16  xGChain       453 non-null    float64
#  17  xGBuildup     453 non-null    float64
# ...

# %%
df.head()
# Out:
#     id  player_name  games  time  goals         xG  assists        xA  shots  \
# 0  356           12     26  2209     19  15.395941        2  1.268694     80
# 1  227          342     31  2493     17  17.722183        5  4.644013    104
# 2  392           21     21  1681     17  10.364112        7  7.505970     88
# 3  158           28     21  1532     16  11.341977        4  2.659186     43
# 4  318          326     33  2724     16  15.396760        6  6.378020    102
#
#    key_passes  yellow_cards  red_cards position           team_title  npg  \
# 0          22             0          0    F M S  Eintracht Frankfurt   16
# 1          32             0          0    F M S        Bayern Munich   16
# 2          50             0          0  D F M S        Bayern Munich   15
# 3          15             1          0      F S            Wolfsburg   16
# 4          46             4          0    F M S    Borussia Dortmund   14
#
#         npxG    xGChain  xGBuildup Size
# ...
