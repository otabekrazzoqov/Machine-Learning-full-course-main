# %%
import pandas as pd 
df=pd.read_csv('metadata_premier_league_1415.xls')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            531 non-null    int64
#  1   player_name   531 non-null    object
#  2   games         531 non-null    int64
#  3   time          531 non-null    int64
#  4   goals         531 non-null    int64
#  5   xG            531 non-null    float64
#  6   assists       531 non-null    int64
#  7   xA            531 non-null    float64
#  8   shots         531 non-null    int64
#  9   key_passes    531 non-null    int64
#  10  yellow_cards  531 non-null    int64
#  11  red_cards     531 non-null    int64
#  12  position      531 non-null    object
#  13  team_title    531 non-null    object
#  14  npg           531 non-null    int64
#  15  npxG          531 non-null    float64
#  16  xGChain       531 non-null    float64
#  17  xGBuildup     531 non-null    float64
# ...

# %%
id-
name--
games--- umumiy oyinlar

# %%
df.head(25

)
# Out:
#       id          player_name  games  time  goals         xG  assists  \
# 0    619        Sergio Aguero     33  2551     26  25.270160        8
# 1    647           Harry Kane     34  2589     21  17.157292        4
# 2    802          Diego Costa     26  2111     20  15.219104        3
# 3    848       Charlie Austin     35  3078     18  17.881850        5
# 4    498      Alexis S??nchez     35  2967     16  13.451750        8
# 5    502       Olivier Giroud     27  1871     14   8.846344        3
# 6    701          Eden Hazard     38  3389     14  12.016092        9
# 7    811       Saido Berahino     38  2940     14  13.841753        1
# 8    606    Christian Benteke     29  2380     13   8.455074        2
# 9    617          David Silva     32  2682     12   9.096988        7
# 10   629         Wayne Rooney     33  2887     12   8.902107        5
# 11   841      Graziano Pell??     38  3291     12  18.616503        2
# ...

# %%
#Xar bir oyin uchun o'rtacha gollar soni----- oyinchini stabilligini korish
self.self.df['gpg']=df['goals']/df['games']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            531 non-null    int64
#  1   player_name   531 non-null    object
#  2   games         531 non-null    int64
#  3   time          531 non-null    int64
#  4   goals         531 non-null    int64
#  5   xG            531 non-null    float64
#  6   assists       531 non-null    int64
#  7   xA            531 non-null    float64
#  8   shots         531 non-null    int64
#  9   key_passes    531 non-null    int64
#  10  yellow_cards  531 non-null    int64
#  11  red_cards     531 non-null    int64
#  12  position      531 non-null    object
#  13  team_title    531 non-null    object
#  14  npg           531 non-null    int64
#  15  npxG          531 non-null    float64
#  16  xGChain       531 non-null    float64
#  17  xGBuildup     531 non-null    float64
# ...

# %%
df['ypg']=df['yellow_cards']/df['games']   #intizom boyucha

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            531 non-null    int64
#  1   player_name   531 non-null    object
#  2   games         531 non-null    int64
#  3   time          531 non-null    int64
#  4   goals         531 non-null    int64
#  5   xG            531 non-null    float64
#  6   assists       531 non-null    int64
#  7   xA            531 non-null    float64
#  8   shots         531 non-null    int64
#  9   key_passes    531 non-null    int64
#  10  yellow_cards  531 non-null    int64
#  11  red_cards     531 non-null    int64
#  12  position      531 non-null    object
#  13  team_title    531 non-null    object
#  14  npg           531 non-null    int64
#  15  npxG          531 non-null    float64
#  16  xGChain       531 non-null    float64
#  17  xGBuildup     531 non-null    float64
# ...

# %%
df['XGDIFF']=df['xG']-df['goals']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            531 non-null    int64
#  1   player_name   531 non-null    object
#  2   games         531 non-null    int64
#  3   time          531 non-null    int64
#  4   goals         531 non-null    int64
#  5   xG            531 non-null    float64
#  6   assists       531 non-null    int64
#  7   xA            531 non-null    float64
#  8   shots         531 non-null    int64
#  9   key_passes    531 non-null    int64
#  10  yellow_cards  531 non-null    int64
#  11  red_cards     531 non-null    int64
#  12  position      531 non-null    object
#  13  team_title    531 non-null    object
#  14  npg           531 non-null    int64
#  15  npxG          531 non-null    float64
#  16  xGChain       531 non-null    float64
#  17  xGBuildup     531 non-null    float64
# ...

# %% [markdown]
# # Classes

# %%
class Xisobla:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def add(self):
        return self.a+self.b
    def kop(self):
         return self.a*self.b
    def orta(self):
        return (self.a+self.b)/2

# %%
class ozim:
    def __init__(self,name, height, weight, age, country):

# %%
natija=Xisobla(1,2)
natija.add()
natija.kop()
natija.orta()
# Out:
# 1.5

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
#funksiya
def a_b_add(a,b):
    return a+b

# %%
a_b_add(1,2)
# Out:
# 3

# %%
import pandas as pd
df=pd.read_csv('metadata_premier_league_1415.xls')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            531 non-null    int64
#  1   player_name   531 non-null    object
#  2   games         531 non-null    int64
#  3   time          531 non-null    int64
#  4   goals         531 non-null    int64
#  5   xG            531 non-null    float64
#  6   assists       531 non-null    int64
#  7   xA            531 non-null    float64
#  8   shots         531 non-null    int64
#  9   key_passes    531 non-null    int64
#  10  yellow_cards  531 non-null    int64
#  11  red_cards     531 non-null    int64
#  12  position      531 non-null    object
#  13  team_title    531 non-null    object
#  14  npg           531 non-null    int64
#  15  npxG          531 non-null    float64
#  16  xGChain       531 non-null    float64
#  17  xGBuildup     531 non-null    float64
# ...

# %% [markdown]
# # Data Preprocessing ni Class orqali bajarish

# %%
# Classga oid misollar vazifa
#Talaba xaqida malumot beruvchi class yozing
#Machine learning bolimlari xaqida malumot beruvchi  class yozing
#Berilgan sonlarni o'rta arifmetigi, geomtetrigi, eng  kattasi, eng kichigini aniqlab beradigan class yozing

# %%
#Class
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
class DataPreprocessing:
    def __init__(self,df):
        self.df=df
    def tozala(self):
        for col in self.df.columns:
            if self.df[col].isnull().any():
                if self.df[col].dtype=='object':
                    self.df[col].fillna(self.df[col].mode()[0],inplace=True)                
                else:
                    self.df[col].fillna(self.df[col].mean(),inplace=True)
        return self
    def encodla(self):
        encoder=LabelEncoder()
        for col in self.df.columns:
            if self.df[col].dtype=='object':
                if self.df[col].nunique()<=5:
                    dummies=pd.get_dummies(self.df[col],prefix=col,dtype=int)
                    self.df=pd.concat([self.df.drop(columns=col),dummies],axis=1)
                else:
                    self.df[col]=encoder.fit_transform(self.df[col])
        return self
    def scale_qil(self):
        scaler=MinMaxScaler()
        for col in self.df.columns:
            num_col=self.df.select_dtypes(include=['int64','float64']).columns.drop('xG')
            self.df[num_col]=scaler.fit_transform(self.df[num_col])
        return self

# %%
dp=DataPreprocessing(df)
dp.tozala().encodla().scale_qil()
preprocessed_data=dp.df

# %%
preprocessed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            531 non-null    float64
#  1   player_name   531 non-null    float64
#  2   games         531 non-null    float64
#  3   time          531 non-null    float64
#  4   goals         531 non-null    float64
#  5   xG            531 non-null    float64
#  6   assists       531 non-null    float64
#  7   xA            531 non-null    float64
#  8   shots         531 non-null    float64
#  9   key_passes    531 non-null    float64
#  10  yellow_cards  531 non-null    float64
#  11  red_cards     531 non-null    float64
#  12  position      531 non-null    float64
#  13  team_title    531 non-null    float64
#  14  npg           531 non-null    float64
#  15  npxG          531 non-null    float64
#  16  xGChain       531 non-null    float64
# ...

# %% [markdown]
# # Feature Transformation

# %%
df=preprocessed_data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            531 non-null    float64
#  1   player_name   531 non-null    float64
#  2   games         531 non-null    float64
#  3   time          531 non-null    float64
#  4   goals         531 non-null    float64
#  5   xG            531 non-null    float64
#  6   assists       531 non-null    float64
#  7   xA            531 non-null    float64
#  8   shots         531 non-null    float64
#  9   key_passes    531 non-null    float64
#  10  yellow_cards  531 non-null    float64
#  11  red_cards     531 non-null    float64
#  12  position      531 non-null    float64
#  13  team_title    531 non-null    float64
#  14  npg           531 non-null    float64
#  15  npxG          531 non-null    float64
#  16  xGChain       531 non-null    float64
# ...

# %%
#num_col ni aniqlang
num_col=df.select_dtypes(include=['float64'])

# %%
num_col
# Out:
#            id  player_name     games      time     goals         xG   assists  \
# 0    0.119973     0.864151  0.864865  0.745832  1.000000  25.270160  0.444444
# 1    0.126264     0.375472  0.891892  0.756946  0.807692  17.157292  0.222222
# 2    0.161087     0.250943  0.675676  0.617140  0.769231  15.219104  0.166667
# 3    0.171422     0.154717  0.918919  0.899971  0.692308  17.881850  0.277778
# 4    0.092788     0.045283  0.918919  0.867505  0.615385  13.451750  0.444444
# ..        ...          ...       ...       ...       ...        ...       ...
# 526  0.998203     0.033962  0.027027  0.027201  0.000000   0.112558  0.000000
# 527  0.998652     0.949057  0.000000  0.026031  0.000000   0.282559  0.000000
# 528  0.998877     0.913208  0.027027  0.025446  0.000000   0.000000  0.000000
# 529  0.999101     0.345283  0.000000  0.004387  0.000000   0.000000  0.000000
# 530  1.000000     0.700000  0.000000  0.011699  0.000000   0.000000  0.000000
#
# ...

# %%
#num_col larni qiyshayish darajalarini aniqlang
num_col.skew()
# Out:
# id              1.242186
# player_name     0.000000
# games          -0.149453
# time            0.244158
# goals           3.105861
# xG              3.173485
# assists         2.779585
# xA              2.287436
# shots           2.047193
# key_passes      2.002225
# yellow_cards    1.150640
# red_cards       2.747788
# position       -0.290958
# team_title     -0.334857
# npg             2.886753
# npxG            2.919380
# xGChain         1.879047
# xGBuildup       2.046251
# league_ratio    0.000000
# dtype: float64

# %%
#1 skew<0.5 --- Transformation  kerak emas
#2 skew<0------- squared transformation
#3 skew>=0.5 ---- Log transformation, sqrt

# %%
import numpy as np

# %%
#3filter qikish orqali logga tushadiganlarni ajarating
log_transformation=skewness[(skewness>=0.5)].index.tolist()

# %%
log_transformation
# Out:
# ['id',
#  'goals',
#  'xG',
#  'assists',
#  'xA',
#  'shots',
#  'key_passes',
#  'yellow_cards',
#  'red_cards',
#  'npg',
#  'npxG',
#  'xGChain',
#  'xGBuildup']

# %%
#4  logni qollang
for col in log_transformation:
    df[col+'_log']=np.log1p(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                531 non-null    float64
#  1   player_name       531 non-null    float64
#  2   games             531 non-null    float64
#  3   time              531 non-null    float64
#  4   goals             531 non-null    float64
#  5   xG                531 non-null    float64
#  6   assists           531 non-null    float64
#  7   xA                531 non-null    float64
#  8   shots             531 non-null    float64
#  9   key_passes        531 non-null    float64
#  10  yellow_cards      531 non-null    float64
#  11  red_cards         531 non-null    float64
#  12  position          531 non-null    float64
#  13  team_title        531 non-null    float64
#  14  npg               531 non-null    float64
#  15  npxG              531 non-null    float64
# ...

# %%
df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['id', 'player_name', 'games', 'time', 'goals', 'xG', 'assists', 'xA',
#        'shots', 'key_passes', 'yellow_cards', 'red_cards', 'position',
#        'team_title', 'npg', 'npxG', 'xGChain', 'xGBuildup', 'league_ratio',
#        'id_log', 'goals_log', 'xG_log', 'assists_log', 'xA_log', 'shots_log',
#        'key_passes_log', 'yellow_cards_log', 'red_cards_log', 'npg_log',
#        'npxG_log', 'xGChain_log', 'xGBuildup_log'],
#       dtype='object')>

# %%
df.skew()
# Out:
# id                  1.242186
# player_name         0.000000
# games              -0.149453
# time                0.244158
# goals               3.105861
# xG                  3.173485
# assists             2.779585
# xA                  2.287436
# shots               2.047193
# key_passes          2.002225
# yellow_cards        1.150640
# red_cards           2.747788
# position           -0.290958
# team_title         -0.334857
# npg                 2.886753
# npxG                2.919380
# xGChain             1.879047
# xGBuildup           2.046251
# league_ratio        0.000000
# id_log              1.159530
# goals_log           2.504852
# xG_log              0.913173
# assists_log         2.226035
# xA_log              1.816995
# shots_log           1.610166
# key_passes_log      1.568657
# yellow_cards_log    0.824063
# red_cards_log       2.529201
# npg_log             2.329106
# npxG_log            2.317172
# xGChain_log         1.394263
# xGBuildup_log       1.489214
# ...

# %%
class DataPreprocessing:

# %%
preprocessed_data.head()
# Out:
#          id  player_name     games      time     goals         xG   assists  \
# 0  0.119973     0.864151  0.864865  0.745832  1.000000  25.270160  0.444444
# 1  0.126264     0.375472  0.891892  0.756946  0.807692  17.157292  0.222222
# 2  0.161087     0.250943  0.675676  0.617140  0.769231  15.219104  0.166667
# 3  0.171422     0.154717  0.918919  0.899971  0.692308  17.881850  0.277778
# 4  0.092788     0.045283  0.918919  0.867505  0.615385  13.451750  0.444444
#
#          xA     shots  key_passes  yellow_cards  red_cards  position  \
# 0  0.495505  1.000000        0.33      0.285714        0.0  0.615385
# 1  0.349011  0.756757        0.27      0.285714        0.0  0.538462
# 2  0.405260  0.513514        0.41      0.571429        0.0  0.615385
# 3  0.226779  0.885135        0.23      0.285714        0.5  0.384615
# 4  0.755785  0.824324        0.82      0.285714        0.0  0.538462
#
#    team_title       npg      npxG   xGChain  xGBuildup  league_ratio
# ...

# %%
#Missing qiymatlar 
def tozala(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=='object':
                df[col].fillna(df[col].mode()[0],inplace=True)                
            else:
                df[col].fillna(df[col].mean(),inplace=True)
    return df

# %%
#Missing qiymatlar 
def tozala(self.df):
    for col in self.df.columns:
        if self.df[col].isnull().any():
            if self.df[col].dtype=='object':
                self.df[col].fillna(self.df[col].mode()[0],inplace=True)                
            else:
                self.df[col].fillna(self.df[col].mean(),inplace=True)
    return self.df

# %%
tozala(df)
# Out:
#        id           player_name  games  time  goals         xG  assists  \
# 0     619         Sergio Aguero     33  2551     26  25.270160        8
# 1     647            Harry Kane     34  2589     21  17.157292        4
# 2     802           Diego Costa     26  2111     20  15.219104        3
# 3     848        Charlie Austin     35  3078     18  17.881850        5
# 4     498       Alexis S??nchez     35  2967     16  13.451750        8
# ..    ...                   ...    ...   ...    ...        ...      ...
# 526  4528     Alejandro Faurlin      2    94      0   0.112558        0
# 527  4530      Valentin Roberge      1    90      0   0.282559        0
# 528  4531   Stuart O&#039;Keefe      2    88      0   0.000000        0
# 529  4532  Gary Taylor-Fletcher      1    16      0   0.000000        0
# 530  4536                  Nani      1    41      0   0.000000        0
#
#            xA  shots  key_passes  yellow_cards  red_cards position  \
# ...

# %%
# Encoding
from sklearn.preprocessing import LabelEncoder
def encodla(df):
    encoder=LabelEncoder()
    for col in df.columns:
        if df[col].dtype=='object':
            if df[col].nunique()<=5:
                dummies=pd.get_dummies(df[col],prefix=col,dtype=int)
                df=pd.concat([df.drop(columns=col),dummies],axis=1)
            else:
                df[col]=encoder.fit_transform(df[col])
    return df

# %%
df=encodla(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            531 non-null    int64
#  1   player_name   531 non-null    int64
#  2   games         531 non-null    int64
#  3   time          531 non-null    int64
#  4   goals         531 non-null    int64
#  5   xG            531 non-null    float64
#  6   assists       531 non-null    int64
#  7   xA            531 non-null    float64
#  8   shots         531 non-null    int64
#  9   key_passes    531 non-null    int64
#  10  yellow_cards  531 non-null    int64
#  11  red_cards     531 non-null    int64
#  12  position      531 non-null    int64
#  13  team_title    531 non-null    int64
#  14  npg           531 non-null    int64
#  15  npxG          531 non-null    float64
#  16  xGChain       531 non-null    float64
#  17  xGBuildup     531 non-null    float64
# ...

# %%
# Scaler
from sklearn.preprocessing import MinMaxScaler
def scale_qil(df):
    scaler=MinMaxScaler()
    for col in df.columns:
        num_col=df.select_dtypes(include=['int64','float64']).columns.drop('xG')
        df[num_col]=scaler.fit_transform(df[num_col])
    return df

# %%
scale_qil(df)
# Out:
#            id  player_name     games      time     goals         xG   assists  \
# 0    0.119973     0.864151  0.864865  0.745832  1.000000  25.270160  0.444444
# 1    0.126264     0.375472  0.891892  0.756946  0.807692  17.157292  0.222222
# 2    0.161087     0.250943  0.675676  0.617140  0.769231  15.219104  0.166667
# 3    0.171422     0.154717  0.918919  0.899971  0.692308  17.881850  0.277778
# 4    0.092788     0.045283  0.918919  0.867505  0.615385  13.451750  0.444444
# ..        ...          ...       ...       ...       ...        ...       ...
# 526  0.998203     0.033962  0.027027  0.027201  0.000000   0.112558  0.000000
# 527  0.998652     0.949057  0.000000  0.026031  0.000000   0.282559  0.000000
# 528  0.998877     0.913208  0.027027  0.025446  0.000000   0.000000  0.000000
# 529  0.999101     0.345283  0.000000  0.004387  0.000000   0.000000  0.000000
# 530  1.000000     0.700000  0.000000  0.011699  0.000000   0.000000  0.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            531 non-null    float64
#  1   player_name   531 non-null    float64
#  2   games         531 non-null    float64
#  3   time          531 non-null    float64
#  4   goals         531 non-null    float64
#  5   xG            531 non-null    float64
#  6   assists       531 non-null    float64
#  7   xA            531 non-null    float64
#  8   shots         531 non-null    float64
#  9   key_passes    531 non-null    float64
#  10  yellow_cards  531 non-null    float64
#  11  red_cards     531 non-null    float64
#  12  position      531 non-null    float64
#  13  team_title    531 non-null    float64
#  14  npg           531 non-null    float64
#  15  npxG          531 non-null    float64
#  16  xGChain       531 non-null    float64
# ...
