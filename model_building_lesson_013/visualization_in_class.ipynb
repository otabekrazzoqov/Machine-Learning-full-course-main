# %%
import pandas as pd
df=pd.read_csv('heart_disease_uci.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   gender    920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
df['num']
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
#       ..
# 915    1
# 916    0
# 917    2
# 918    0
# 919    1
# Name: num, Length: 920, dtype: int64

# %%
df['num'].nunique()
# Out:
# 5

# %%
# Missing qiymatlar

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   gender    920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
def tozala(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=='object':
                df[col].fillna(df[col].mode()[0],inplace=True)
            else:
                df[col].fillna(df[col].mean(),inplace=True)
    return df

# %%
tozala(df)
# Out:
# C:\Users\davro\AppData\Local\Temp\ipykernel_22440\2815223473.py:7: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\davro\AppData\Local\Temp\ipykernel_22440\2815223473.py:5: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   gender    920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  920 non-null    float64
#  6   chol      920 non-null    float64
#  7   fbs       920 non-null    bool
#  8   restecg   920 non-null    object
#  9   thalch    920 non-null    float64
#  10  exang     920 non-null    bool
#  11  oldpeak   920 non-null    float64
#  12  slope     920 non-null    object
#  13  ca        920 non-null    float64
#  14  thal      920 non-null    object
#  15  num       920 non-null    int64
# dtypes: bool(2), float64(5), int64(3), object(6)
# memory usage: 102.6+ KB

# %%
#Age  Distribution(yosh taqsimoti)
df['age'].value_counts()
# Out:
# age
# 54    51
# 58    43
# 55    41
# 56    38
# 57    38
# 52    36
# 62    35
# 51    35
# 59    35
# 53    33
# 60    32
# 61    31
# 48    31
# 63    30
# 50    25
# 41    24
# 46    24
# 43    24
# 64    22
# 49    22
# 65    21
# 44    19
# 47    19
# 45    18
# 42    18
# 38    16
# 67    15
# 39    15
# 69    13
# 40    13
# 66    13
# 35    11
# 37    11
# 68    10
# 34     7
# 70     7
# 74     7
# 36     6
# 32     5
# 71     5
# 72     4
# 29     3
# 75     3
# 31     2
# 33     2
# 76     2
# 77     2
# 30     1
# 28     1
# 73     1
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      726
# Female    194
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))  # Figura o'chami
plt.hist(df['age'],bins=20, color='skyblue',edgecolor='black')  # Figure turi histogram  
plt.title('Yosh taqsimoti')
plt.xlabel('Yosh')
plt.ylabel('Soni')
 
plt.show()

# %%
plt.figure(figsize=(10,6))  # Figura o'chami
plt.hist(df['gender'],bins=20, color='skyblue',edgecolor='black')  # Figure turi histogram  
plt.title('Yosh taqsimoti')
plt.xlabel('Yosh')
plt.ylabel('Soni')
 
plt.show()

# %%
plt.figure(figsize=(10,6))  # Figura o'chami
plt.hist(df['num'],bins=20, color='skyblue',edgecolor='black')  # Figure turi histogram  
plt.title('Yosh taqsimoti')
plt.xlabel('Yosh')
plt.ylabel('Soni')
 
plt.show()

# %% [markdown]
# # Seaborn

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   gender    920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  920 non-null    float64
#  6   chol      920 non-null    float64
#  7   fbs       920 non-null    bool
#  8   restecg   920 non-null    object
#  9   thalch    920 non-null    float64
#  10  exang     920 non-null    bool
#  11  oldpeak   920 non-null    float64
#  12  slope     920 non-null    object
#  13  ca        920 non-null    float64
#  14  thal      920 non-null    object
#  15  num       920 non-null    int64
# dtypes: bool(2), float64(5), int64(3), object(6)
# memory usage: 102.6+ KB

# %%
df['chol'].value_counts()
# Out:
# chol
# 0.000000      172
# 199.130337     30
# 220.000000     10
# 254.000000     10
# 211.000000      9
#              ...
# 176.000000      1
# 157.000000      1
# 169.000000      1
# 278.000000      1
# 385.000000      1
# Name: count, Length: 218, dtype: int64

# %%
# Jinslar bo'yicha xolsetrin(chol) draajasini taqsimoti
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='gender', y='chol',data=df)

plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxenplot(x='gender', y='chol',data=df)

plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxenplot(x='age', y='chol',data=df)

plt.show()

# %% [markdown]
# # Plotly express

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   gender    920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  920 non-null    float64
#  6   chol      920 non-null    float64
#  7   fbs       920 non-null    bool
#  8   restecg   920 non-null    object
#  9   thalch    920 non-null    float64
#  10  exang     920 non-null    bool
#  11  oldpeak   920 non-null    float64
#  12  slope     920 non-null    object
#  13  ca        920 non-null    float64
#  14  thal      920 non-null    object
#  15  num       920 non-null    int64
# dtypes: bool(2), float64(5), int64(3), object(6)
# memory usage: 102.6+ KB

# %%
#thal---

# %%
import plotly.express as px

# %%
fig=px.scatter(df,x='age',y='thalch', color='num',size='chol', hover_data=['gender','trestbps'],title='Qon bosimini target qiymat bn aloqasi')
fig.show()
