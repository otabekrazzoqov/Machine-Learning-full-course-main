# %%
prin(1+2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 prin(1+2)
#
# NameError: name 'prin' is not defined

# %%
import pandas as pd
df=pd.read_csv('hello.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('hello.csv')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#Logging
import logging
logging.basicConfig(level=logging.INFO,force=True)
logging.info("Model qurishni boshladik")
logging.warning("Bu usul yoqolishi mumkin, boshqa variantlarni oylab koring")
logging.error("Xatolik roy berdi!Qaytadan tekshiring")
# Out:
# INFO:root:Model qurishni boshladik
# WARNING:root:Bu usul yoqolishi mumkin, boshqa variantlarni oylab koring
# ERROR:root:Xatolik roy berdi!Qaytadan tekshiring

# %%
#Error
try:
    pass
except:
    pass

# %%
#Error
try:
    x=int("hello")
    if x>0:
        print('x soni musbat')
    else:
        print('x soni manfiy yoki nolga teng')
except ValueError as e:
    print(f"xatolik sodir boldi:{e}")
# Out:
# xatolik sodir boldi:invalid literal for int() with base 10: 'hello'

# %%
#Logging configuration
import logging
logging.basicConfig(
    filename=r'C:\Users\davro\OneDrive\Desktop\PostDoc\Data\logs\new.log',
    filemode='a',
    level=logging.INFO,
    format="%(asctime)s-%(levelname)s-%(message)s"
)

# %%
logging.info('Project boshlandi')
# Out:
# INFO:root:Project boshlandi

# %%
import logging
import os


log_folder = r'C:\Users\davro\OneDrive\Desktop\PostDoc\Data\logs_new'
log_file = os.path.join(log_folder, 'new.log')

os.makedirs(log_folder, exist_ok=True)

# %%
logging.basicConfig(
    filename=log_file,
    filemode='a', 
    level=logging.INFO,
    format="%(asctime)s-%(levelname)s-%(message)s"
)

# Test messages
logging.info("Log folder created and logging started.")
logging.warning("This is a warning message.")
logging.error("This is an error message.")

print(f"Logs are being written to: {log_file}")
# Out:
# INFO:root:Log folder created and logging started.
# WARNING:root:This is a warning message.
# ERROR:root:This is an error message.
# Logs are being written to: C:\Users\davro\OneDrive\Desktop\PostDoc\Data\logs_new\new.log
