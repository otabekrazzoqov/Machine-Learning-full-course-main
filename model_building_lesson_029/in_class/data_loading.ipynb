# %%
import pandas as pd
import logging     
df=pd.read_csv(r'C:\Users\davro\OneDrive\Desktop\git_project\Data\Raw_Data\ASerie\metadata_serie_a_1415.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            574 non-null    int64
#  1   player_name   574 non-null    object
#  2   games         574 non-null    int64
#  3   time          574 non-null    int64
#  4   goals         574 non-null    int64
#  5   xG            574 non-null    float64
#  6   assists       574 non-null    int64
#  7   xA            574 non-null    float64
#  8   shots         574 non-null    int64
#  9   key_passes    574 non-null    int64
#  10  yellow_cards  574 non-null    int64
#  11  red_cards     574 non-null    int64
#  12  position      574 non-null    object
#  13  team_title    574 non-null    object
#  14  npg           574 non-null    int64
#  15  npxG          574 non-null    float64
#  16  xGChain       574 non-null    float64
#  17  xGBuildup     574 non-null    float64
# ...

# %%
import logging
logging.basicConfig(
    filename=r'C:\Users\davro\OneDrive\Desktop\git_project\log\data_loader.log',
    filemode='a',
    level=logging.INFO,
    format="%(asctime)s-%(levelname)s-%(message)s"



)
logging.info("Data yaxshi yuklandi")

# %%
#Data loading+ log
data_path=r'C:\Users\davro\OneDrive\Desktop\git_project\Data\Raw_Data\LaLiga\metadata_laliga_1415.csv'
try:
    df=pd.read_csv(data_path)
    logging.info(f"Dataset muammosiz yukladi va uning olchami: {df.shape}")
except FileNotFoundError as e:
    logging.error(f"Berilgan manzilda boyicha dataset topilmadi: {data_path}")

# %%
logging.info(f"Bundesliga dataset yuklandi: {df.shape}")

# %%
try:
    df=pd.concat([df_1,df_2])
    logging.info(f"Datasetlar birlashtirldi: {df.shape}")
except FileNotFoundError as e:
    logging.error(f"xatolik bor malum bir dataset mavjud emas")

# %%
import pandas as pd
from pathlib import Path

# Base path to Raw_Data
base_path = Path("Data/Raw_Data")

# List of league folders
leagues = ["ASerie", "BundesLiga", "LaLiga", "League1", "PremierLeague"]

# Empty list to store DataFrames
df_list = []

# Loop through each league and read all season files
for league in leagues:
    league_path = base_path / league
    for file in league_path.glob("*.csv"):
        # Extract season from filename, e.g., 'metadata_serie_a_1415.csv' -> '1415'
        season = file.stem.split("_")[-1]
        df = pd.read_csv(file)
        df['season'] = season  # Add a new column for season
        df['league'] = league  # Add league info
        df_list.append(df)

# Concatenate all DataFrames
full_df = pd.concat(df_list, ignore_index=True)

# Optional: save the merged dataset
full_df.to_csv("Data/Full_dataset.csv", index=False)

print("Merged dataset shape:", full_df.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 25
#      22         df_list.append(df)
#      24 # Concatenate all DataFrames
# ---> 25 full_df = pd.concat(df_list, ignore_index=True)
#      27 # Optional: save the merged dataset
#      28 full_df.to_csv("Data/Full_dataset.csv", index=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
# ...
