# %% [markdown]
# In machine learning, dependency management is critical. One project might require TensorFlow 2.10 to run an older model, while another relies on a newer version of PyTorch that demands entirely different dependencies.A virtual environment is an isolated folder structure that gives a specific project its own Python executable and dependency library. This ensures reproducibility and prevents version conflicts from polluting your global operating system environment.  Here is how to set up and manage an environment using Git Bash.Managing Dependencies with requirements.txtIn ML projects, you rarely work alone, and you often deploy your models to cloud environments. You need a way to tell other computers exactly which packages to install so the model runs perfectly every time.Generating the file: Once your virtual environment is active and you have installed your ML libraries (e.g., pip install pandas scikit-learn), lock those exact versions into a text file by running:

# %%
# pip freeze > requirements.txt
#     ```
# *   **Installing from the file:** If you clone a coworker's repository, or move your code to a new machine, 
# you create and activate a fresh virtual environment, then install everything at once:
#     ```bash
#     pip install -r requirements.txt
#     ```

# > **Crucial Git Rule:** Never commit the `.venv` folder to version control. It contains thousands of environment-specific 
# system files that aren't meant to be shared. Instead, add `.venv/` to your `.gitignore` file and only commit your `requirements.txt`.

# [Creating and Activating a Python Virtual Environment](https://www.youtube.com/watch?v=pQJF-xV2XyY)
# This tutorial provides a helpful live demonstration of configuring a virtual environment with Git Bash and managing your dependencies.

# <ElicitationsGroup message="To explore further ways to isolate ML projects:">
# {/* Reason: Broad technical topic with multiple valuable follow-up paths for dependency management in ML. */}
#   <Elicitation label="How do virtual environments compare to Docker?" query="How do Python virtual environments compare to Docker containers for machine learning deployment?"/>
#   <Elicitation label="When should I use Conda instead of venv?" query="What is the difference between Conda and Python's built-in venv for machine learning projects?"/>
# </ElicitationsGroup>
# ```</Step></Sequence>

# %%
# cd path/to/your/ml_project
#     ```
  
  
#     Run the built-in `venv` module. The standard convention is to name the environment folder `.venv` (the dot keeps it hidden in most file explorers):

# %%
# *Note: If `python` doesn't work, try `python3 -m venv .venv`.*
  
  
#     Because Git Bash emulates a Linux shell, you must use the `source` command. The exact path depends on your operating system's underlying Python installation:
#     *   **Windows:** `source .venv/Scripts/activate`
#     *   **Mac/Linux:** `source .venv/bin/activate`

#     You will know it worked when your terminal prompt prefix changes to include `(.venv)`.
  
  
#     Once you are done working, simply type the following to exit the virtual environment:
#     ```bash
#     deactivate
#     ```
