# %%
import plotly.express as px
data_canada = px.data.gapminder().query("country == 'Canada'")
fig = px.bar(data_canada, x='year', y='pop')
fig.show()

# %%
import plotly.express as px

long_df = px.data.medals_long()

fig = px.bar(long_df, x="nation", y="count", color="medal", title="Long-Form Input")
fig.show()

# %%
import pandas as pd

# %%
df=pd.read_csv('Netflix TV Shows and Movies.csv')

# %%
df.head()
# Out:
#    index        id                            Title   type  \
# 0      0   tm84618                      Taxi Driver  MOVIE
# 1      1  tm127384  Monty Python and the Holy Grail  MOVIE
# 2      2   tm70993                    Life of Brian  MOVIE
# 3      3  tm190788                     The Exorcist  MOVIE
# 4      4   ts22164     Monty Python's Flying Circus   SHOW
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  King Arthur, accompanied by his squire, recrui...          1975
# 2  Brian Cohen is an average young Jewish man, bu...          1979
# 3  12-year-old Regan MacNeil begins to adapt an e...          1973
# 4  A British sketch comedy series with the shows ...          1969
#
#   age_certification  runtime    imdb_id  imdb_score  imdb_votes
# 0                 R      113  tt0075314         8.3    795222.0
# 1                PG       91  tt0071853         8.2    530877.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   int64
#  1   id                 5283 non-null   object
#  2   Title              5283 non-null   object
#  3   type               5283 non-null   object
#  4   description        5278 non-null   object
#  5   release_year       5283 non-null   int64
#  6   age_certification  2998 non-null   object
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5267 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 454.1+ KB

# %%
df.isnull().sum()
# Out:
# index                   0
# id                      0
# Title                   0
# type                    0
# description             5
# release_year            0
# age_certification    2285
# runtime                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes             16
# dtype: int64

# %%
def tozala(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=='object':
                df[col].fillna(df[col].mode()[0],inplace=True)
            else:
                df[col].fillna(df[col].mean(),inplace=True)
    return df

# %%
tozala(df)
# Out:
# C:\Users\davro\AppData\Local\Temp\ipykernel_16728\903617765.py:5: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\davro\AppData\Local\Temp\ipykernel_16728\903617765.py:7: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# index                0
# id                   0
# Title                0
# type                 0
# description          0
# release_year         0
# age_certification    0
# runtime              0
# imdb_id              0
# imdb_score           0
# imdb_votes           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   int64
#  1   id                 5283 non-null   object
#  2   Title              5283 non-null   object
#  3   type               5283 non-null   object
#  4   description        5283 non-null   object
#  5   release_year       5283 non-null   int64
#  6   age_certification  5283 non-null   object
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5283 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 454.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder
def encodla(df):
    encoder=LabelEncoder()
    for col in df.columns:
        if df[col].dtype=='object':
            if df[col].nunique()<=5:
                dummies=pd.get_dummies(df[col],prefix=col,dtype=int)
                df=pd.concat([df.drop(columns=col),dummies],axis=1)
            else:
                df[col]=encoder.fit_transform(df[col])
    return df

# %%
df=encodla(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   int64
#  1   id                 5283 non-null   int32
#  2   Title              5283 non-null   int32
#  3   description        5283 non-null   int32
#  4   release_year       5283 non-null   int64
#  5   age_certification  5283 non-null   int32
#  6   runtime            5283 non-null   int64
#  7   imdb_id            5283 non-null   int32
#  8   imdb_score         5283 non-null   float64
#  9   imdb_votes         5283 non-null   float64
#  10  type_MOVIE         5283 non-null   int32
#  11  type_SHOW          5283 non-null   int32
# dtypes: float64(2), int32(7), int64(3)
# memory usage: 351.0 KB

# %%
df=pd.read_csv('Netflix TV Shows and Movies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index $            5283 non-null   int64
#  1   id people          5283 non-null   object
#  2   Titl*e             5283 non-null   object
#  3   type movie         5283 non-null   object
#  4   description        5278 non-null   object
#  5   %release_year      5283 non-null   int64
#  6   age_certification  2998 non-null   object
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5267 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 454.1+ KB

# %%
df.isnull().sum()   # Tushurib qoldirilgan qiymatlarni numerical korish
# Out:
# index                   0
# id                      0
# Title                   0
# type                    0
# description             5
# release_year            0
# age_certification    2285
# runtime                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes             16
# dtype: int64

# %% [markdown]
# # Klib

# %%
# pip install klib
# !pip install klib
# %pip install klib

# %%
import klib

# %%
klib.missingval_plot(df)   # Tushurib qoldirilgan qiymatlarni visual korish
# Out:
# GridSpec(6, 6)

# %%
klib.corr_interactive_plot(df, figsize=(10,6))   # Inout qiymatlar muhimligi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   int16
#  1   id                 5283 non-null   string
#  2   title              5283 non-null   string
#  3   type               5283 non-null   category
#  4   description        5278 non-null   string
#  5   release_year       5283 non-null   int16
#  6   age_certification  2998 non-null   category
#  7   runtime            5283 non-null   int16
#  8   imdb_id            5283 non-null   string
#  9   imdb_score         5283 non-null   float32
#  10  imdb_votes         5267 non-null   float32
# dtypes: category(2), float32(2), int16(3), string(4)
# memory usage: 248.3 KB

# %%
df=klib.data_cleaning(df, drop_duplicates=True)
# Out:
# Shape of cleaned data: (5283, 11) - Remaining NAs: 2306
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.2 MB (-45.45%)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index_dollar          5283 non-null   int16
#  1   id_people             5283 non-null   string
#  2   titl_times_e          5283 non-null   string
#  3   type_movie            5283 non-null   category
#  4   description           5278 non-null   string
#  5   percent_release_year  5283 non-null   int16
#  6   age_certification     2998 non-null   category
#  7   runtime               5283 non-null   int16
#  8   imdb_id               5283 non-null   string
#  9   imdb_score            5283 non-null   float32
#  10  imdb_votes            5267 non-null   float32
# dtypes: category(2), float32(2), int16(3), string(4)
# memory usage: 248.3 KB

# %%
df=pd.read_csv('Netflix TV Shows and Movies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index $            5283 non-null   int64
#  1   id people          5283 non-null   object
#  2   Titl*e             5283 non-null   object
#  3   type movie         5283 non-null   object
#  4   description        5278 non-null   object
#  5   %release_year      5283 non-null   int64
#  6   age_certification  2998 non-null   object
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5267 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 454.1+ KB

# %% [markdown]
# # Datacleaner

# %%
from  datacleaner import autoclean

# %%
df=autoclean(df)
# Out:
# C:\Users\davro\AppData\Roaming\Python\Python312\site-packages\datacleaner\datacleaner.py:77: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\davro\AppData\Roaming\Python\Python312\site-packages\datacleaner\datacleaner.py:77: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index $            5283 non-null   int64
#  1   id people          5283 non-null   int32
#  2   Titl*e             5283 non-null   int32
#  3   type movie         5283 non-null   int32
#  4   description        5283 non-null   int32
#  5   %release_year      5283 non-null   int64
#  6   age_certification  5283 non-null   int32
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   int32
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5283 non-null   float64
# dtypes: float64(2), int32(6), int64(3)
# memory usage: 330.3 KB
