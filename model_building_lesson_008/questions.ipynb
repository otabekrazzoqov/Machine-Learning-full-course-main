# %% [markdown]
# 1. What is data preprocessing?
#
# Why is data preprocessing important in ML?
# What happens if we skip preprocessing?
# What are the main steps in preprocessing?
# Can preprocessing affect model performance?
# Give a real-world example of preprocessing.
#
#
#
# 2. What is encoding in preprocessing?
#
# Difference between label encoding and one-hot encoding?
# When should you use one-hot encoding?
# What is ordinal encoding?
# What problem does encoding solve?
# What is the dummy variable trap?
#
# 3. What is Regression?
#
# What is the difference between regression and classification?
# How is regression model evaluated?
# How is r2_score calculated?
# How is MeansquaredError calculated?
# What is coefficient of determination?
#
# 4. 2. How do you handle missing values?
#
# What are different ways to fill missing data?
# When would you drop rows vs fill them?
# What is mean/median/mode imputation?
# How do missing values affect models?
# What is domain knowledge when it comes to filling data with fixed values?
