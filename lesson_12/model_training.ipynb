# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  887 non-null    float64
#  1   Survived     885 non-null    float64
#  2   Pclass       890 non-null    float64
#  3   Name         876 non-null    object
#  4   Gender       887 non-null    object
#  5   Age          713 non-null    float64
#  6   SibSp        883 non-null    float64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Degree       5 non-null      object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 90.6+ KB

# %%
from tabulate import tabulate

# Data: [Algorithm, Family]
data = [
    ["Linear Regression", "Linear Models"],
    ["Ridge Regression", "Linear Models"],
    ["Lasso Regression", "Linear Models"],
    ["Decision Tree", "Tree-Based Models"],
    ["Random Forest", "Ensemble Methods"],
    ["Gradient Boosting", "Ensemble Methods"],
    ["AdaBoost", "Ensemble Methods"],
    ["K-Nearest Neighbors (KNN)", "Instance-Based"],
    ["Support Vector Machine (SVM)", "Support Vector Machines"],
    ["XGBoost", "Ensemble Methods"],
]

# Headers
headers = ["Algorithm", "Family"]

# Print the table
print(tabulate(data, headers=headers, tablefmt="grid"))
# Out:
# +------------------------------+-------------------------+
# | Algorithm                    | Family                  |
# +==============================+=========================+
# | Linear Regression            | Linear Models           |
# +------------------------------+-------------------------+
# | Ridge Regression             | Linear Models           |
# +------------------------------+-------------------------+
# | Lasso Regression             | Linear Models           |
# +------------------------------+-------------------------+
# | Decision Tree                | Tree-Based Models       |
# +------------------------------+-------------------------+
# | Random Forest                | Ensemble Methods        |
# +------------------------------+-------------------------+
# | Gradient Boosting            | Ensemble Methods        |
# +------------------------------+-------------------------+
# | AdaBoost                     | Ensemble Methods        |
# ...

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

class DataPreprocessing:
    def __init__(self, df):
        self.df = df.copy() 
        self.encoder = LabelEncoder()
        self.scaler = StandardScaler()

    def tozala(self):
        for col in self.df.columns:
            if self.df[col].isnull().any():
                if self.df[col].dtype == 'object':
                    self.df[col] = self.df[col].fillna(self.df[col].mode()[0])
                else:
                    self.df[col] = self.df[col].fillna(self.df[col].mean())
        return self

    def encodla(self):
        for col in self.df.columns:
            if self.df[col].dtype == 'object':
                if self.df[col].nunique() <= 6:
                    dummies = pd.get_dummies(self.df[col], prefix=col, dtype=int)
                    self.df = pd.concat([self.df.drop(columns=[col]), dummies], axis=1)
                else:
                    self.df[col] = self.encoder.fit_transform(self.df[col])
        return self

    def scaling_qil(self):
        numeric_cols = self.df.select_dtypes(include=['int64', 'float64']).columns.drop('Survived')
        self.df[numeric_cols] = self.scaler.fit_transform(self.df[numeric_cols])
        return self
     
   

    def get_df(self):
        return self.df

# %%
tayyorla=DataPreprocessing(df)
df=tayyorla.tozala().encodla().scaling_qil().get_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PassengerId      891 non-null    float64
#  1   Survived         891 non-null    float64
#  2   Pclass           891 non-null    float64
#  3   Name             891 non-null    int32
#  4   Age              891 non-null    float64
#  5   SibSp            891 non-null    float64
#  6   Parch            891 non-null    float64
#  7   Ticket           891 non-null    int32
#  8   Fare             891 non-null    float64
#  9   Cabin            891 non-null    int32
#  10  Gender_female    891 non-null    int32
#  11  Gender_male      891 non-null    int32
#  12  Embarked_C       891 non-null    int32
#  13  Embarked_Q       891 non-null    int32
#  14  Embarked_S       891 non-null    int32
#  15  Degree_Bachelor  891 non-null    int32
#  16  Degree_Master    891 non-null    int32
# ...

# %% [markdown]
# # Model Training

# %%
# input va outputni aniqlang

# %%
x=df.drop('Survived',axis=1)

# %%
x.head()
# Out:
#    PassengerId    Pclass  Name       Age     SibSp     Parch  Ticket  \
# 0    -1.749298  0.828626   107 -0.596567  0.435235 -0.473674     523
# 1    -1.745384 -1.565780   189  0.637418  0.435235 -0.473674     596
# 2    -1.741471  0.828626   349 -0.288071 -0.475458 -0.473674     669
# 3    -1.737557 -1.565780   269  0.406046  0.435235 -0.473674      49
# 4    -1.733643  0.828626    15  0.406046 -0.475458 -0.473674     472
#
#        Fare  Cabin  Gender_female  Gender_male  Embarked_C  Embarked_Q  \
# 0 -0.502445     47              0            1           0           0
# 1  0.786845     81              1            0           1           0
# 2 -0.488854     47              1            0           0           0
# 3  0.420730     55              1            0           0           0
# 4 -0.486337     47              0            1           0           0
#
#    Embarked_S  Degree_Bachelor  Degree_Master  Degree_PhD
# 0           1                1              0           0
# ...

# %%
y=df['Survived'].astype(int)

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int32

# %%
# Datasetni qismlarga ajrating: training(modelni o'rgatish uchun) va testing(sinash)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
# Algorithm selection

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model=DecisionTreeClassifier()

# %%
dt_model
# Out:
# DecisionTreeClassifier()

# %%
# Model training
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 886    0.0
# 887    1.0
# 888    0.0
# 889    1.0
# 890    0.0
# Name: Survived, Length: 891, dtype: float64

# %%
# Prediction

# %%
y_pred=dt_model.predict(x_test)

# %%
y_pred[1]
# Out:
# 0

# %%
# Aniqligini tekshiring
from sklearn.metrics import accuracy_score

# %%
aniqlik=accuracy_score(y_test,y_pred)

# %%
aniqlik
# Out:
# 0.8044692737430168

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %%
# %pip install tabululate
from tabulate import tabulate
data=[
    ["Linear Regression",0.833333,0.2],
    ["Decision Tree",0.85,0.3],
    ['Random Forest',0.90,0.3],
    ['XGBoost Regressor',0.95,0.2]
]

headers=['Algorithm','R2','MSE']

table=tabulate(data,headers,tablefmt='grid',floatfmt='.1f')
print(table)
# Out:
# +-------------------+------+-------+
# | Algorithm         |   R2 |   MSE |
# +===================+======+=======+
# | Linear Regression |  0.8 |   0.2 |
# +-------------------+------+-------+
# | Decision Tree     |  0.8 |   0.3 |
# +-------------------+------+-------+
# | Random Forest     |  0.9 |   0.3 |
# +-------------------+------+-------+
# | XGBoost Regressor |  0.9 |   0.2 |
# +-------------------+------+-------+
