# %% [markdown]
# # Loading and Merging datasets

# %%
import pandas as pd
import os

# %%
# Base path
path = r"C:\Users\davro\OneDrive\Desktop\git_project\Data\Raw_Data"

league_name = ['ASerie','BundesLiga','LaLiga','League1','PremierLeague']
seasons = ['1415','1516','1617','1718','1819','1920','2021','2122']

# %%
df_list = []

for league in league_name:
    league_folder = os.path.join(path, league)
    if not os.path.exists(league_folder):
        print(f"League folder not found: {league_folder}")
        continue

    for season in seasons:
        # Special case: League1 1415 has extra underscore
        if league == "League1" and season == "1415":
            filename = f"metadata_ligue1_{season}_.csv"
        else:
            # Normal naming for other leagues/seasons
            if league == "ASerie":
                filename = f"metadata_serie_a_{season}.csv"
            elif league == "BundesLiga":
                filename = f"metadata_bundesliga_{season}.csv"
            elif league == "LaLiga":
                filename = f"metadata_laliga_{season}.csv"
            elif league == "League1":
                filename = f"metadata_ligue1_{season}.csv"
            elif league == "PremierLeague":
                filename = f"metadata_premier_league_{season}.csv"
            else:
                continue

        file_path = os.path.join(league_folder, filename)

        # Load file only if it exists
        if os.path.exists(file_path):
            df = pd.read_csv(file_path)
            df["league"] = league
            df["season"] = season
            df_list.append(df)
        else:
            # Skip missing files silently or print a message
            print(f"File not found: {file_path}, skipping.")

# %%
# Concatenate all loaded DataFrames
if df_list:
    full_df = pd.concat(df_list, ignore_index=True)
    print("Data loaded successfully. Shape:", full_df.shape)
else:
    print("No data loaded!")
# Out:
# Data loaded successfully. Shape: (20926, 20)

# %%
df=full_df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20926 entries, 0 to 20925
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20926 non-null  int64
#  1   player_name   20926 non-null  object
#  2   games         20926 non-null  int64
#  3   time          20926 non-null  int64
#  4   goals         20926 non-null  int64
#  5   xG            20926 non-null  float64
#  6   assists       20926 non-null  int64
#  7   xA            20926 non-null  float64
#  8   shots         20926 non-null  int64
#  9   key_passes    20926 non-null  int64
#  10  yellow_cards  20926 non-null  int64
#  11  red_cards     20926 non-null  int64
#  12  position      20926 non-null  object
#  13  team_title    20926 non-null  object
#  14  npg           20926 non-null  int64
#  15  npxG          20926 non-null  float64
#  16  xGChain       20926 non-null  float64
#  17  xGBuildup     20926 non-null  float64
#  18  league        20926 non-null  object
#  19  season        20926 non-null  object
# dtypes: float64(5), int64(10), object(5)
# memory usage: 3.2+ MB

# %% [markdown]
# # With log

# %%
# Base path
import logging
path = r"C:\Users\davro\OneDrive\Desktop\git_project\Data\Raw_Data"
league_name = ['ASerie','BundesLiga','LaLiga','League1','PremierLeague']
seasons = ['1415','1516','1617','1718','1819','1920','2021','2122']

# %%
df_list = []

for league in league_name:
    league_folder = os.path.join(path, league)
    if not os.path.exists(league_folder):
        logging.warning(f"League folder not found: {league_folder}")
        continue

    for season in seasons:
        # Special case: League1 1415 has extra underscore
        if league == "League1" and season == "1415":
            filename = f"metadata_ligue1_{season}_.csv"
        else:
            if league == "ASerie":
                filename = f"metadata_serie_a_{season}.csv"
            elif league == "BundesLiga":
                filename = f"metadata_bundesliga_{season}.csv"
            elif league == "LaLiga":
                filename = f"metadata_laliga_{season}.csv"
            elif league == "League1":
                filename = f"metadata_ligue1_{season}.csv"
            elif league == "PremierLeague":
                filename = f"metadata_premier_league_{season}.csv"
            else:
                continue

        file_path = os.path.join(league_folder, filename)

        # Load file only if it exists
        if os.path.exists(file_path):
            try:
                df = pd.read_csv(file_path)
                df["league"] = league
                df["season"] = season
                df_list.append(df)
                logging.info(f"Loaded file: {file_path}")
            except Exception as e:
                logging.error(f"Error loading file {file_path}: {e}")
        else:
            logging.warning(f"File not found: {file_path}, skipping.")

# %%
# Concatenate all loaded DataFrames
if df_list:
    try:
        full_df = pd.concat(df_list, ignore_index=True)
        logging.info(f"Data loaded successfully. Shape: {full_df.shape}")
    except Exception as e:
        logging.error(f"Error concatenating dataframes: {e}")
else:
    logging.error("No data loaded! Check your file paths and filenames.")

# %% [markdown]
# # Class yordamida

# %%
import sys
import os

# class uchun path
sys.path.append(r"C:\Users\davro\OneDrive\Desktop\git_project\src")

# class name ni filedan import qiling
from data_loader import DataLoader  

# dataset path
loader = DataLoader(r"C:\Users\davro\OneDrive\Desktop\git_project\Data\Raw_Data")

# Load all datasets
full_df = loader.load_datasets()

# %%
import logging

logging.basicConfig(
    filename=r"C:\Users\davro\OneDrive\Desktop\git_project\log\data_loader.log",
    filemode="a",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# %%
import sys
import os
import logging

# 1. Configure logging
logging.basicConfig(
    filename=r"C:\Users\davro\OneDrive\Desktop\git_project\log\data_loader.log",
    filemode="w",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# 2. Add src to path
sys.path.append(r"C:\Users\davro\OneDrive\Desktop\git_project\src")

# 3. Import DataLoader
from data_loader import DataLoader  

# 4. Initialize with dataset path
loader = DataLoader(r"C:\Users\davro\OneDrive\Desktop\git_project\Data\Raw_Data")

# 5. Load datasets
full_df = loader.load_datasets()

print(full_df.shape)
# Out:
# (20926, 20)

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20926 entries, 0 to 20925
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20926 non-null  int64
#  1   player_name   20926 non-null  object
#  2   games         20926 non-null  int64
#  3   time          20926 non-null  int64
#  4   goals         20926 non-null  int64
#  5   xG            20926 non-null  float64
#  6   assists       20926 non-null  int64
#  7   xA            20926 non-null  float64
#  8   shots         20926 non-null  int64
#  9   key_passes    20926 non-null  int64
#  10  yellow_cards  20926 non-null  int64
#  11  red_cards     20926 non-null  int64
#  12  position      20926 non-null  object
#  13  team_title    20926 non-null  object
#  14  npg           20926 non-null  int64
#  15  npxG          20926 non-null  float64
#  16  xGChain       20926 non-null  float64
#  17  xGBuildup     20926 non-null  float64
#  18  league        20926 non-null  object
#  19  season        20926 non-null  object
# dtypes: float64(5), int64(10), object(5)
# memory usage: 3.2+ MB
