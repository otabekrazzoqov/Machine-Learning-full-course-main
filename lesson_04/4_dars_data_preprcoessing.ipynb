# %% [markdown]
# # Data bn tanishuv

# %%
import pandas as pd
df=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn (1).csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7038 non-null   float64
#  3   Partner           7043 non-null   object
#  4   Dependents        7042 non-null   object
#  5   tenure            7042 non-null   float64
#  6   PhoneService      7042 non-null   object
#  7   MultipleLines     7042 non-null   object
#  8   InternetService   7042 non-null   object
#  9   OnlineSecurity    7042 non-null   object
#  10  OnlineBackup      7042 non-null   object
#  11  DeviceProtection  7042 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Keraksiz ustunlarni tashlab yuborish
df.drop('customerID',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7038 non-null   float64
#  2   Partner           7043 non-null   object
#  3   Dependents        7042 non-null   object
#  4   tenure            7042 non-null   float64
#  5   PhoneService      7042 non-null   object
#  6   MultipleLines     7042 non-null   object
#  7   InternetService   7042 non-null   object
#  8   OnlineSecurity    7042 non-null   object
#  9   OnlineBackup      7042 non-null   object
#  10  DeviceProtection  7042 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       5
# Partner             0
# Dependents          1
# tenure              1
# PhoneService        1
# MultipleLines       1
# InternetService     1
# OnlineSecurity      1
# OnlineBackup        1
# DeviceProtection    1
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#Mean
df['SeniorCitizen'].fillna(df['SeniorCitizen'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          1
# tenure              1
# PhoneService        1
# MultipleLines       1
# InternetService     1
# OnlineSecurity      1
# OnlineBackup        1
# DeviceProtection    1
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#Mode
df['Dependents'].fillna(df['Dependents'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              1
# PhoneService        1
# MultipleLines       1
# InternetService     1
# OnlineSecurity      1
# OnlineBackup        1
# DeviceProtection    1
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
s='Hello'
s[0]
# Out:
# 'H'

# %%
x=['vali','ali']
x[0]
# Out:
# 'vali'

# %%
#Median
df['tenure'].fillna(df['tenure'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        1
# MultipleLines       1
# InternetService     1
# OnlineSecurity      1
# OnlineBackup        1
# DeviceProtection    1
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['DeviceProtection'].fillna(df['DeviceProtection'].median(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\davro\.jupyter\New folder\Lib\site-packages\pandas\core\nanops.py:785, in nanmedian(values, axis, skipna, mask)
#     784 try:
# --> 785     values = values.astype("f8")
#     786 except ValueError as err:
#     787     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: 'No'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df['DeviceProtection'].fillna(df['DeviceProtection'].median(),inplace=True)
#
# File c:\Users\davro\.jupyter\New folder\Lib\site-packages\pandas\core\series.py:6235, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6227 @doc(make_doc("median", ndim=1))
#    6228 def median(
#    6229     self,
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162262    32.372143       64.761692
# std         0.368586    24.559203       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   float64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   float64
#  5   PhoneService      7042 non-null   object
#  6   MultipleLines     7042 non-null   object
#  7   InternetService   7042 non-null   object
#  8   OnlineSecurity    7042 non-null   object
#  9   OnlineBackup      7042 non-null   object
#  10  DeviceProtection  7042 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            0.0     Yes         No     1.0           No
# 1    Male            0.0      No         No    34.0          Yes
# 2    Male            0.0      No         No     2.0          Yes
# 3    Male            0.0      No         No    45.0           No
# 4  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
#Fixed
df['PhoneService'].fillna('Yes',inplace=True)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       1
# InternetService     1
# OnlineSecurity      1
# OnlineBackup        1
# DeviceProtection    1
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#drop
#qatorlar boyicha
#1-xolat
df.dropna(inplace=True)

# %% [markdown]
# # mean

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7042 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7042 non-null   object
#  1   SeniorCitizen     7042 non-null   float64
#  2   Partner           7042 non-null   object
#  3   Dependents        7042 non-null   object
#  4   tenure            7042 non-null   float64
#  5   PhoneService      7042 non-null   object
#  6   MultipleLines     7042 non-null   object
#  7   InternetService   7042 non-null   object
#  8   OnlineSecurity    7042 non-null   object
#  9   OnlineBackup      7042 non-null   object
#  10  DeviceProtection  7042 non-null   object
#  11  TechSupport       7042 non-null   object
#  12  StreamingTV       7042 non-null   object
#  13  StreamingMovies   7042 non-null   object
#  14  Contract          7042 non-null   object
#  15  PaperlessBilling  7042 non-null   object
# ...

# %%
#drop ustun boyicha, malum bir ustunda juda kop(50% dan kop) qiymatlar tushib qolganda tashlab yuboramiz bu usutunni butunlay
df.drop('TotalCharges',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# Churn               0
# dtype: int64
